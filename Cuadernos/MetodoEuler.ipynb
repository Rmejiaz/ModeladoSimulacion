# %% [markdown]
# <a href="https://colab.research.google.com/github/Rmejiaz/ModeladoSimulacion/blob/main/Cuadernos/MetodoEuler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Método de Euler para la solución de ecuaciones diferenciales
#
# Implementación del método de euler junto con algunos ejemplos
#
# ### Rafael Mejía Zuluaga

# %% [markdown]
# $\dot x = f(x)$
#
# $x_1 = x_0 + hf(x_0)$
#
# $x_2 = x_1 + hf(x_1)$
#
# ...
#
# $x_{n+1} = x_n + hf(x_n)$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def euler_method(f, h, x0, ti, tf):
  N = int((tf-ti)/h)
  x = np.zeros(N)
  x[0] = x0
  for i in range(len(x)-1):
    x[i+1] = x[i] + h*f(x[i])

  t = np.linspace(ti,tf,N)
  
  return t,x

# %% [markdown]
# ## Ejemplo:
#
# ### $\dot x = \sin(x)$

# %%
plt.figure(figsize=(16,9))
for i in np.linspace(-2*np.pi,2*np.pi,15):
  t,x = euler_method(np.sin,0.1,i,0,10)
  plt.plot(t,x,label=f'$x_0 = {i}$')
  plt.legend()
plt.xlabel("t",fontsize=15)
plt.ylabel("x(t)",fontsize=15)
plt.show()

# %% [markdown]
# ### $\dot x = x^2$

# %%
def func(x):
  return x**2

plt.figure(figsize=(16,9))
for i in np.linspace(-3,3,15):
  t,x=euler_method(func,0.01,i,0,0.3,)
  plt.plot(t,x,label=f'$x_0 = {i}$')
  plt.legend()
plt.xlabel("t",fontsize=15)
plt.ylabel("x(t)",fontsize=15)
plt.show()
